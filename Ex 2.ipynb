# %%
import pandas as pd

# %%
so_data = pd.read_csv('survey_results_public.csv')

# %%
so_data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
so_data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
so_data.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
so_data.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp         Country    CurrencyDesc  ...  \
# 0  Monthly        NaN            NaN         Germany   European Euro  ...
# 1      NaN        NaN            NaN  United Kingdom  Pound sterling  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# ...

# %%
so_data.tail()
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64456            NaN  United States          NaN  ...        NaN          NaN
# 64457            NaN        Morocco          NaN  ...        NaN          NaN
# 64458            NaN       Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN         Poland          NaN  ...        NaN          NaN
# 64460            NaN          Spain          NaN  ...        NaN          NaN
#
# ...

# %%
so_data.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# ...

# %%
so_data.shape
# Out:
# (64461, 61)

# %%
so_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
so_data.duplicated().sum()
# Out:
# 0

# %%
sample_data = [['Jack',10],['Jill',11],['Harry',12],['Harry',12],['Vin',13],['Jake',14],['Jake',14],['Jake',14]]

# %%
sample_df = pd.DataFrame(sample_data, columns = ['Name', 'Age'])
sample_df
# Out:
#     Name  Age
# 0   Jack   10
# 1   Jill   11
# 2  Harry   12
# 3  Harry   12
# 4    Vin   13
# 5   Jake   14
# 6   Jake   14
# 7   Jake   14

# %%
sample_df.duplicated().sum()
# Out:
# 3

# %%
sample_df.drop_duplicates(inplace=True)

# %%
sample_df.duplicated().sum()
# Out:
# 0

# %%
sample_df
# Out:
#     Name  Age
# 0   Jack   10
# 1   Jill   11
# 2  Harry   12
# 4    Vin   13
# 5   Jake   14

# %%
so_data.isnull()
# Out:
#        Respondent  MainBranch  Hobbyist    Age  Age1stCode  CompFreq  \
# 0           False       False     False   True       False     False
# 1           False       False     False   True       False      True
# 2           False       False     False   True       False      True
# 3           False       False     False  False       False      True
# 4           False       False     False  False       False      True
# ...           ...         ...       ...    ...         ...       ...
# 64456       False        True     False   True       False      True
# 64457       False        True     False   True        True      True
# 64458       False        True     False   True        True      True
# 64459       False        True     False   True        True      True
# 64460       False        True     False   True        True      True
#
#        CompTotal  ConvertedComp  Country  CurrencyDesc  ...  SurveyEase  \
# ...

# %%
so_data.isnull().sum()
# Out:
# Respondent                0
# MainBranch              299
# Hobbyist                 45
# Age                   19015
# Age1stCode             6561
#                       ...
# WebframeWorkedWith    22182
# WelcomeChange         11778
# WorkWeekHrs           23310
# YearsCode              6777
# YearsCodePro          18112
# Length: 61, dtype: int64

# %%
 so_data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
so_data.drop(['CompTotal'], axis=1, inplace=True)

# %%
so_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
so_data['MainBranch'].isnull().sum()
# Out:
# 299

# %%
so_data['MainBranch'].nunique()
# Out:
# 5

# %%
so_data['MainBranch'].unique()
# Out:
# array(['I am a developer by profession', 'I code primarily as a hobby',
#        'I used to be a developer by profession, but no longer am',
#        'I am not primarily a developer, but I write code sometimes as part of my work',
#        'I am a student who is learning to code', nan], dtype=object)

# %%
so_data['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   47193
# I am a student who is learning to code                                            7970
# I am not primarily a developer, but I write code sometimes as part of my work     5502
# I code primarily as a hobby                                                       2314
# I used to be a developer by profession, but no longer am                          1183
# Name: MainBranch, dtype: int64

# %%
so_data['MainBranch'].fillna(so_data['MainBranch'].mode, inplace=True)

# %%
so_data['MainBranch'].isnull().sum()
# Out:
# 0

# %%
so_data['Hobbyist'].isnull().sum()
# Out:
# 45

# %%
so_data['Hobbyist'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
so_data['Hobbyist'].fillna('Yes', inplace=True)

# %%
so_data['Hobbyist'].isnull().sum()
# Out:
# 0

# %%
so_data['Hobbyist'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
so_data['CurrencyDesc'].head(15)
# Out:
# 0            European Euro
# 1           Pound sterling
# 2                      NaN
# 3             Albanian lek
# 4                      NaN
# 5            European Euro
# 6     United States dollar
# 7     United States dollar
# 8     United States dollar
# 9           Pound sterling
# 10          Pound sterling
# 11           European Euro
# 12           European Euro
# 13    United States dollar
# 14                     NaN
# Name: CurrencyDesc, dtype: object

# %%
so_data['CurrencyDesc'].fillna(method='ffill', inplace=True)

# %%
so_data['CurrencyDesc'].head(15)
# Out:
# 0            European Euro
# 1           Pound sterling
# 2           Pound sterling
# 3             Albanian lek
# 4             Albanian lek
# 5            European Euro
# 6     United States dollar
# 7     United States dollar
# 8     United States dollar
# 9           Pound sterling
# 10          Pound sterling
# 11           European Euro
# 12           European Euro
# 13    United States dollar
# 14    United States dollar
# Name: CurrencyDesc, dtype: object

# %%
so_data['Age'].head(15)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3     25.0
# 4     31.0
# 5      NaN
# 6      NaN
# 7     36.0
# 8     30.0
# 9     22.0
# 10    23.0
# 11    49.0
# 12    53.0
# 13    27.0
# 14     NaN
# Name: Age, dtype: float64

# %%
so_data['Age'].fillna(method='bfill',limit=1, inplace=True)

# %%
so_data['Age'].head(15)
# Out:
# 0      NaN
# 1      NaN
# 2     25.0
# 3     25.0
# 4     31.0
# 5      NaN
# 6     36.0
# 7     36.0
# 8     30.0
# 9     22.0
# 10    23.0
# 11    49.0
# 12    53.0
# 13    27.0
# 14    45.0
# Name: Age, dtype: float64

# %%
so_data.describe()
# Out:
#          Respondent           Age  ConvertedComp   WorkWeekHrs
# count  64461.000000  54431.000000   3.475600e+04  41151.000000
# mean   32554.079738     30.793496   1.037561e+05     40.782174
# std    18967.442360      9.543127   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   9.500000e+04     44.000000
# max    65639.000000    279.000000   2.000000e+06    475.000000

# %%
so_data.sample(5)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21884       21969                     I am a developer by profession      Yes
# 27937       28041                        I code primarily as a hobby      Yes
# 12131       12170  I am not primarily a developer, but I write co...       No
# 44227       45116                     I am a developer by profession       No
# 21935       22020                     I am a developer by profession      Yes
#
#         Age Age1stCode CompFreq  ConvertedComp  Country     CurrencyDesc  \
# 21884  29.0         14  Monthly        26100.0    Kenya  Kenyan shilling
# 27937  18.0          8      NaN            NaN   Canada   Egyptian pound
# 12131  28.0         15      NaN            NaN   Serbia    Serbian dinar
# 44227  21.0         13  Monthly        33732.0  Germany    European Euro
# 21935  30.0         15   Yearly        71345.0   France    European Euro
#
# ...

# %%
so_data.nlargest(5,'Age')
# Out:
#        Respondent                              MainBranch Hobbyist    Age  \
# 14375       14419          I am a developer by profession      Yes  279.0
# 2510         2522          I am a developer by profession      Yes   99.0
# 2625         2638          I am a developer by profession       No   99.0
# 5926         5950          I am a developer by profession      Yes   99.0
# 26740       26839  I am a student who is learning to code      Yes   99.0
#
#           Age1stCode CompFreq  ConvertedComp        Country  \
# 14375             16   Yearly        52968.0    Netherlands
# 2510              16   Weekly      2000000.0  United States
# 2625   Older than 85   Yearly      1000000.0         Canada
# 5926              10  Monthly        30000.0    South Korea
# 26740             17      NaN            NaN          India
#
#                CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# 14375         European Euro            EUR  ...                        Easy
# ...

# %%
so_data.nsmallest(5,'Age')
# Out:
#        Respondent                              MainBranch Hobbyist  Age  \
# 12271       12310  I am a student who is learning to code      Yes  1.0
# 20042       20122          I am a developer by profession      Yes  1.0
# 25060       25153  I am a student who is learning to code      Yes  1.0
# 25061       25154          I am a developer by profession      Yes  1.0
# 54687       55797          I am a developer by profession      Yes  1.0
#
#                  Age1stCode CompFreq  ConvertedComp        Country  \
# 12271                    23      NaN            NaN        Nigeria
# 20042                    20  Monthly      1000000.0      Indonesia
# 25060                     7      NaN            NaN        Armenia
# 25061                    12   Yearly        75669.0    Netherlands
# 54687  Younger than 5 years  Monthly           48.0  United States
#
#                CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# ...

# %%
so_data.groupby('MainBranch').get_group('I am a student who is learning to code')
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 14             15  I am a student who is learning to code      Yes  45.0
# 20             21  I am a student who is learning to code      Yes  23.0
# 27             28  I am a student who is learning to code      Yes  18.0
# 28             29  I am a student who is learning to code      Yes  18.0
# 34             35  I am a student who is learning to code      Yes  16.0
# ...           ...                                     ...      ...   ...
# 64078       65548  I am a student who is learning to code      Yes   NaN
# 64126       65601  I am a student who is learning to code       No   NaN
# 64149       65626  I am a student who is learning to code       No   NaN
# 64160       65637  I am a student who is learning to code      Yes   NaN
# 64161       65639  I am a student who is learning to code       No  24.0
#
#       Age1stCode CompFreq  ConvertedComp        Country          CurrencyDesc  \
# ...

# %%
so_data_new = so_data.loc[1:1000]

# %%
so_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    1000 non-null   int64
#  1   MainBranch                    1000 non-null   object
#  2   Hobbyist                      1000 non-null   object
#  3   Age                           981 non-null    float64
#  4   Age1stCode                    992 non-null    object
#  5   CompFreq                      731 non-null    object
#  6   ConvertedComp                 673 non-null    float64
#  7   Country                       1000 non-null   object
#  8   CurrencyDesc                  1000 non-null   object
#  9   CurrencySymbol                818 non-null    object
#  10  DatabaseDesireNextYear        746 non-null    object
#  11  DatabaseWorkedWith            851 non-null    object
# ...

# %%
so_data_new.loc[:15]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# 11          12                     I am a developer by profession       No
# ...

# %%
so_data_new.loc[so_data_new.Country == 'United States']
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 4             5  I used to be a developer by profession, but no...      Yes
# 7             8                     I am a developer by profession      Yes
# 13           14                     I am a developer by profession      Yes
# 16           17                     I am a developer by profession      Yes
# 17           18                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 986         990  I am not primarily a developer, but I write co...       No
# 991         995                     I am a developer by profession      Yes
# 992         996                     I am a developer by profession       No
# 997        1001                     I am a developer by profession       No
# 998        1002                        I code primarily as a hobby      Yes
#
# ...

# %%
so_data_new.loc[(so_data_new.Country == 'United States') & (so_data_new.Age <25)]
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 18           19                     I am a developer by profession       No
# 34           35             I am a student who is learning to code      Yes
# 39           40             I am a student who is learning to code      Yes
# 48           49                     I am a developer by profession       No
# 52           53                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 869         871                        I code primarily as a hobby      Yes
# 883         885  I am not primarily a developer, but I write co...       No
# 888         891                     I am a developer by profession       No
# 911         915                     I am a developer by profession      Yes
# 952         956                     I am a developer by profession      Yes
#
# ...

# %%
so_data_new.loc[(so_data_new.Age <=25), ['Age', 'MainBranch', 'Country']]
# Out:
#       Age                                         MainBranch  \
# 2    25.0                        I code primarily as a hobby
# 3    25.0                     I am a developer by profession
# 9    22.0                     I am a developer by profession
# 10   23.0                     I am a developer by profession
# 16   25.0                     I am a developer by profession
# ..    ...                                                ...
# 993  24.0                     I am a developer by profession
# 994  18.0  I am not primarily a developer, but I write co...
# 995  24.0                     I am a developer by profession
# 996  24.0                     I am a developer by profession
# 999  25.0                     I am a developer by profession
#
#                 Country
# 2    Russian Federation
# 3               Albania
# 9        United Kingdom
# 10       United Kingdom
# 16        United States
# ..                  ...
# 993               India
# 994             Germany
# ...

# %%
so_data_new.iloc[[0,5,10,15]]
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 1            2  I am a developer by profession       No   NaN         19
# 6            7  I am a developer by profession      Yes  36.0         18
# 11          12  I am a developer by profession       No  49.0         42
# 16          17  I am a developer by profession      Yes  25.0         14
#
#    CompFreq  ConvertedComp         Country          CurrencyDesc  \
# 1       NaN            NaN  United Kingdom        Pound sterling
# 6   Monthly            NaN           India  United States dollar
# 11  Monthly        14268.0           Spain         European Euro
# 16   Yearly        79000.0   United States  United States dollar
#
#    CurrencySymbol  ... SurveyEase           SurveyLength Trans  \
# 1             GBP  ...        NaN                    NaN   NaN
# 6             USD  ...        NaN                    NaN   NaN
# 11            EUR  ...       Easy  Appropriate in length    No
# ...

# %%
so_data_new = so_data.iloc[:1000]

# %%
so_data_new.iloc[[0,5,10,15]]
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0            1  I am a developer by profession      Yes   NaN         13
# 5            6  I am a developer by profession       No   NaN         14
# 10          11  I am a developer by profession      Yes  23.0         13
# 15          16  I am a developer by profession      Yes  45.0          8
#
#    CompFreq  ConvertedComp         Country    CurrencyDesc CurrencySymbol  \
# 0   Monthly            NaN         Germany   European Euro            EUR
# 5       NaN            NaN         Germany   European Euro            EUR
# 10   Yearly        40070.0  United Kingdom  Pound sterling            GBP
# 15  Monthly       108576.0  United Kingdom  Pound sterling            GBP
#
#     ...                  SurveyEase           SurveyLength Trans  \
# 0   ...  Neither easy nor difficult  Appropriate in length    No
# 5   ...  Neither easy nor difficult  Appropriate in length   NaN
# ...

# %%
so_data_new2 = so_data.iloc[:1000]

# %%
so_data_new2.iloc[[0,5,10,15]]
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0            1  I am a developer by profession      Yes   NaN         13
# 5            6  I am a developer by profession       No   NaN         14
# 10          11  I am a developer by profession      Yes  23.0         13
# 15          16  I am a developer by profession      Yes  45.0          8
#
#    CompFreq  ConvertedComp         Country    CurrencyDesc CurrencySymbol  \
# 0   Monthly            NaN         Germany   European Euro            EUR
# 5       NaN            NaN         Germany   European Euro            EUR
# 10   Yearly        40070.0  United Kingdom  Pound sterling            GBP
# 15  Monthly       108576.0  United Kingdom  Pound sterling            GBP
#
#     ...                  SurveyEase           SurveyLength Trans  \
# 0   ...  Neither easy nor difficult  Appropriate in length    No
# 5   ...  Neither easy nor difficult  Appropriate in length   NaN
# ...

# %%
so_data_new2.iloc[:5, :5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode
# 0   NaN         13
# 1   NaN         19
# 2  25.0         15
# 3  25.0         18
# 4  31.0         16

# %%
so_data_new2.iloc[2:5, :5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode
# 2  25.0         15
# 3  25.0         18
# 4  31.0         16

# %%
so_data_new2.iloc[2:5, 2:5]
# Out:
#   Hobbyist   Age Age1stCode
# 2      Yes  25.0         15
# 3      Yes  25.0         18
# 4      Yes  31.0         16

# %%
so_data_new2.loc[2:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
#
#     Age Age1stCode CompFreq  ConvertedComp             Country  \
# 2  25.0         15      NaN            NaN  Russian Federation
# 3  25.0         18      NaN            NaN             Albania
# 4  31.0         16      NaN            NaN       United States
# 5   NaN         14      NaN            NaN             Germany
#
#      CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# 2  Pound sterling            NaN  ...  Neither easy nor difficult
# 3    Albanian lek            ALL  ...                         NaN
# 4    Albanian lek            NaN  ...                        Easy
# ...

# %%
so_data_new2.iloc[2:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  ConvertedComp             Country  \
# 2  25.0         15      NaN            NaN  Russian Federation
# 3  25.0         18      NaN            NaN             Albania
# 4  31.0         16      NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# 2  Pound sterling            NaN  ...  Neither easy nor difficult
# 3    Albanian lek            ALL  ...                         NaN
# 4    Albanian lek            NaN  ...                        Easy
#
#             SurveyLength Trans  \
# 2  Appropriate in length   NaN
# 3                    NaN    No
# 4              Too short    No
#
# ...

# %%
so_data_new2[['MainBranch','Hobbyist','Age','Country']].sort_values(by='Age')
# Out:
#                                             MainBranch Hobbyist   Age  \
# 767                        I code primarily as a hobby      Yes  11.0
# 578             I am a student who is learning to code      Yes  13.0
# 779             I am a student who is learning to code      Yes  14.0
# 944             I am a student who is learning to code      Yes  14.0
# 945             I am a student who is learning to code      Yes  14.0
# ..                                                 ...      ...   ...
# 845                     I am a developer by profession      Yes   NaN
# 922                     I am a developer by profession      Yes   NaN
# 943  I used to be a developer by profession, but no...       No   NaN
# 958                     I am a developer by profession      Yes   NaN
# 959                     I am a developer by profession       No   NaN
#
#             Country
# 767   United States
# 578  United Kingdom
# 779   United States
# 944           India
# ...

# %%
so_data_new2.query('Age < 23 and Gender == "Woman" ')
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 34           35  I am a student who is learning to code      Yes  16.0
# 39           40  I am a student who is learning to code      Yes  20.0
# 65           66          I am a developer by profession      Yes  21.0
# 84           85          I am a developer by profession      Yes  21.0
# 87           88  I am a student who is learning to code       No  21.0
# 324         326          I am a developer by profession      Yes  21.0
# 457         459             I code primarily as a hobby      Yes  18.0
# 552         554  I am a student who is learning to code      Yes  16.0
# 670         672          I am a developer by profession      Yes  22.0
# 974         978  I am a student who is learning to code      Yes  21.0
#
#     Age1stCode CompFreq  ConvertedComp        Country          CurrencyDesc  \
# 34          13      NaN            NaN  United States         European Euro
# ...

# %%
so_data_new2.query('40 < WorkWeekHrs < 50')
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 17           18  I am a developer by profession      Yes  32.0         12
# 23           24  I am a developer by profession      Yes  45.0         14
# 42           43  I am a developer by profession      Yes  32.0         16
# 43           44  I am a developer by profession       No  32.0         21
# 56           57  I am a developer by profession       No  44.0         12
# ..          ...                             ...      ...   ...        ...
# 979         983  I am a developer by profession       No  38.0          7
# 981         985  I am a developer by profession      Yes  24.0         18
# 984         988  I am a developer by profession      Yes  27.0         12
# 995         999  I am a developer by profession      Yes  24.0         10
# 997        1001  I am a developer by profession       No  39.0         12
#
#     CompFreq  ConvertedComp               Country  \
# ...

# %%
so_data_new.to_csv('Reduced StackOverflow')
