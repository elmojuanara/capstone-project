# %%
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/elmojuanara/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'this', "couldn't", 'into', 'now', "wasn't", 'won', 'under', 'isn', 'if', 'm', "needn't", 'these', 'why', "haven't", 'few', 'on', 'haven', 'it', 'its', 'but', 'a', 'no', 'shan', 'with', 'weren', 'between', 'while', 'couldn', 'ourselves', 'hasn', 'both', 'or', 'in', 'ma', 'had', 'll', "you're", "hadn't", 'your', 'all', "that'll", 'she', 't', "doesn't", 'some', 'mustn', 'i', 'we', 'doesn', "aren't", 'after', 'off', 'does', 'he', "don't", "won't", 'above', "it's", 'have', 'not', 'than', 'nor', 'then', 'will', 'you', 'itself', 'here', 'o', 'more', 'being', "shan't", 'from', 're', 'doing', 'hers', 'having', 'has', 'himself', 'hadn', 'those', 'myself', 'too', "you'd", 'which', "you'll", 'am', 'is', 'during', 'herself', 'other', "she's", 'before', 'just', 'their', "you've", 'there', 'again', 'wasn', 'theirs', 'shouldn', 'against', 'him', 'because', 'mightn', 'so', "weren't", 'were', 'ours', 'aren', 'wouldn', 'over', 'd', 'be', 'at', 'ain', 'most', 'out', 'didn', 'who', 'me', 'the', 'when',
# ...

# %%
data = ''' Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to intelligence displayed by animals and humans. Several important sub-fields of AI research (as opposed to AI itself) have used working definitions of the intelligent agents field of study, which refers to any system that perceives its environment using an AI-component and takes actions (using procedural / hard-coded components) that maximize its chance of achieving its goals.[a] While intelligent agents as systems that use artificial intelligence are an important application of AI, many AI systems do not perform any procedural (hard-coded) steps with the outputs of the AI at all, such as computer vision, speech recognition, or recommender systems (often not even decising on an output from probabilities, but outputting several).'''

# %%
def data_processing(data):
    #Lowercase conversion
    data = data.lower()
    #tokenize the data
    data_tokens = word_tokenize(data)
    #remove_stopwords
    processed_words = [w for w in data_tokens if not w in stop_words]
    return" ".join(processed_words)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/elmojuanara/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data_processed = data_processing(data)

# %%
data
# Out:
# ' Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to intelligence displayed by animals and humans. Several important sub-fields of AI research (as opposed to AI itself) have used working definitions of the intelligent agents field of study, which refers to any system that perceives its environment using an AI-component and takes actions (using procedural / hard-coded components) that maximize its chance of achieving its goals.[a] While intelligent agents as systems that use artificial intelligence are an important application of AI, many AI systems do not perform any procedural (hard-coded) steps with the outputs of the AI at all, such as computer vision, speech recognition, or recommender systems (often not even decising on an output from probabilities, but outputting several).'

# %%
data_processed
# Out:
# 'artificial intelligence ( ai ) intelligence demonstrated machines , opposed intelligence displayed animals humans . several important sub-fields ai research ( opposed ai ) used working definitions intelligent agents field study , refers system perceives environment using ai-component takes actions ( using procedural / hard-coded components ) maximize chance achieving goals . [ ] intelligent agents systems use artificial intelligence important application ai , many ai systems perform procedural ( hard-coded ) steps outputs ai , computer vision , speech recognition , recommender systems ( often even decising output probabilities , outputting several ) .'

# %%
plt.figure(figsize=(15,10), facecolor='none')
wordcloud = WordCloud(background_color='white').generate(data_processed)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import os
os.chdir(r'/Users/elmojuanara/Documents/Doctoral Student/Bismillaah JAIST/PhD Life/Term 2-1/Data Analytics/Python/WordCloud')

# %%
wordcloud.to_file("wordcloud1.png")

# %%
from PIL import Image

# %%
mask = np.array(Image.open('brain.jpg'))

# %%
mwc = WordCloud(background_color='black', mask = mask)
mwc.generate(data_processed)
plt.figure(figsize=(10,10), facecolor=('none'))
plt.imshow(mwc)
plt.axis('off')
plt.show()
