# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
so_data = pd.read_csv('survey_results_public.csv')

# %%
so_data
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
so_data.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
so_data.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
so_data.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
so_data.tail()
# Out:
#        ResponseId                      MainBranch  \
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# ...

# %%
so_data.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
so_data.shape
# Out:
# (83439, 48)

# %%
so_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
so_data.duplicated().sum()
# Out:
# 0

# %%
sample_data = [['Jack', 10],['Jill',11],['Harry',12],['Vin',13],['Jake',14],['Jake',14],['Jake',14]]

# %%
sample_df = pd.DataFrame(sample_data, columns = ['Name', 'Age'])
sample_df
# Out:
#     Name  Age
# 0   Jack   10
# 1   Jill   11
# 2  Harry   12
# 3    Vin   13
# 4   Jake   14
# 5   Jake   14
# 6   Jake   14

# %%
sample_df.duplicated().sum()
# Out:
# 2

# %%
sample_df.drop_duplicates(inplace=True)

# %%
sample_df.duplicated().sum()
# Out:
# 0

# %%
sample_df
# Out:
#     Name  Age
# 0   Jack   10
# 1   Jill   11
# 2  Harry   12
# 3    Vin   13
# 4   Jake   14

# %%
so_data.isnull()
# Out:
#        ResponseId  MainBranch  Employment  Country  US_State  UK_Country  \
# 0           False       False       False    False      True        True
# 1           False       False       False    False      True        True
# 2           False       False       False    False      True        True
# 3           False       False       False    False      True        True
# 4           False       False       False    False      True       False
# ...           ...         ...         ...      ...       ...         ...
# 83434       False       False       False    False     False        True
# 83435       False       False       False    False      True        True
# 83436       False       False       False    False     False        True
# 83437       False       False       False    False      True        True
# 83438       False       False       False    False      True        True
#
#        EdLevel  Age1stCode  LearnCode  YearsCode  ...    Age  Gender  Trans  \
# ...

# %%
so_data.isnull().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EdLevel                           313
# Age1stCode                        196
# LearnCode                         476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# CompTotal                       36256
# CompFreq                        31289
# LanguageHaveWorkedWith           1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
so_data.isnull()
# Out:
#        ResponseId  MainBranch  Employment  Country  US_State  UK_Country  \
# 0           False       False       False    False      True        True
# 1           False       False       False    False      True        True
# 2           False       False       False    False      True        True
# 3           False       False       False    False      True        True
# 4           False       False       False    False      True       False
# ...           ...         ...         ...      ...       ...         ...
# 83434       False       False       False    False     False        True
# 83435       False       False       False    False      True        True
# 83436       False       False       False    False     False        True
# 83437       False       False       False    False      True        True
# 83438       False       False       False    False      True        True
#
#        EdLevel  Age1stCode  LearnCode  YearsCode  ...    Age  Gender  Trans  \
# ...

# %%
so_data.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
so_data.drop(['CompTotal'], axis=1, inplace=True)

# %%
so_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
so_data.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
so_data['Employment'].isnull().sum()
# Out:
# 116

# %%
so_data['Employment'].nunique()
# Out:
# 9

# %%
so_data['Employment'].unique()
# Out:
# array(['Independent contractor, freelancer, or self-employed',
#        'Student, full-time', 'Employed full-time', 'Student, part-time',
#        'I prefer not to say', 'Employed part-time',
#        'Not employed, but looking for work', 'Retired',
#        'Not employed, and not looking for work', nan], dtype=object)

# %%
so_data['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
so_data['Employment'].fillna(so_data['Employment'].mode, inplace=True)

# %%
so_data['Employment'].isnull().sum()
# Out:
# 0

# %%
so_data['Currency'].isnull().sum()
# Out:
# 22359

# %%
so_data['Currency'].unique()
# Out:
# array(['EUR European Euro', nan, 'GBP\tPound sterling',
#        'INR\tIndian rupee', 'SEK\tSwedish krona', 'TRY\tTurkish lira',
#        'CAD\tCanadian dollar', 'SGD\tSingapore dollar',
#        'CHF\tSwiss franc', 'RUB\tRussian ruble',
#        'ILS\tIsraeli new shekel', 'USD\tUnited States dollar',
#        'BRL\tBrazilian real', 'BGN\tBulgarian lev',
#        'AED United Arab Emirates dirham', 'PLN\tPolish zloty',
#        'UZS\tUzbekistani som', 'HUF\tHungarian forint',
#        'PKR\tPakistani rupee', 'ZMW Zambian kwacha',
#        'NGN\tNigerian naira', 'ALL\tAlbanian lek',
#        'BDT\tBangladeshi taka', 'IRR\tIranian rial', 'RON\tRomanian leu',
#        'HRK\tCroatian kuna', 'GEL\tGeorgian lari', 'DKK\tDanish krone',
#        'AMD\tArmenian dram', 'LBP\tLebanese pound', 'BHD\tBahraini dinar',
#        'EGP\tEgyptian pound', 'AUD\tAustralian dollar',
#        'CLP\tChilean peso', 'IDR\tIndonesian rupiah',
#        'RSD\tSerbian dinar', 'KRW\tSouth Korean won',
# ...

# %%
so_data.describe()
# Out:
#          ResponseId  ConvertedCompYearly
# count  83439.000000         4.684400e+04
# mean   41720.000000         1.184262e+05
# std    24086.908893         5.272944e+05
# min        1.000000         1.000000e+00
# 25%    20860.500000         2.702500e+04
# 50%    41720.000000         5.621100e+04
# 75%    62579.500000         1.000000e+05
# max    83439.000000         4.524131e+07

# %%
so_data.sample(5)
# Out:
#        ResponseId                              MainBranch          Employment  \
# 24240       24241          I am a developer by profession  Employed full-time
# 83242       83243          I am a developer by profession  Employed full-time
# 30682       30683          I am a developer by profession  Employed full-time
# 23199       23200  I am a student who is learning to code  Student, full-time
# 14066       14067          I am a developer by profession  Employed full-time
#
#                         Country US_State UK_Country  \
# 24240                   Belgium      NaN        NaN
# 83242  United States of America     Iowa        NaN
# 30682               South Korea      NaN        NaN
# 23199                    Greece      NaN        NaN
# 14066                  Bulgaria      NaN        NaN
#
#                                             EdLevel     Age1stCode  \
# 24240  Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# ...

# %%
so_data.nlargest(5,'Responseld')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Responseld'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
so_data.groupby('Country').get_group('South Korea')
# Out:
#        ResponseId                                         MainBranch  \
# 549           550  I am not primarily a developer, but I write co...
# 685           686             I am a student who is learning to code
# 1430         1431                     I am a developer by profession
# 1862         1863                     I am a developer by profession
# 5917         5918             I am a student who is learning to code
# ...           ...                                                ...
# 81582       81583                                      None of these
# 82036       82037             I am a student who is learning to code
# 82096       82097                     I am a developer by profession
# 83366       83367                     I am a developer by profession
# 83402       83403                     I am a developer by profession
#
#                Employment      Country US_State UK_Country  \
# 549    Employed full-time  South Korea      NaN        NaN
# ...

# %%
so_data_new = so_data.loc[1:1000]

# %%
so_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    1000 non-null   int64
#  1   MainBranch                    1000 non-null   object
#  2   Employment                    1000 non-null   object
#  3   Country                       1000 non-null   object
#  4   US_State                      152 non-null    object
#  5   UK_Country                    75 non-null     object
#  6   EdLevel                       993 non-null    object
#  7   Age1stCode                    998 non-null    object
#  8   LearnCode                     982 non-null    object
#  9   YearsCode                     939 non-null    object
#  10  YearsCodePro                  738 non-null    object
#  11  DevType                       797 non-null    object
# ...

# %%
so_data_new.loc[10:15]
# Out:
#     ResponseId                                         MainBranch  \
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# 13          14             I am a student who is learning to code
# 14          15  I used to be a developer by profession, but no...
# 15          16             I am a student who is learning to code
#
#                             Employment  \
# 10                  Employed full-time
# 11                  Employed full-time
# 12                  Employed full-time
# 13                  Employed full-time
# 14  Not employed, but looking for work
# 15                  Student, full-time
#
#                                               Country  US_State UK_Country  \
# 10  United Kingdom of Great Britain and Northern I...       NaN    England
# ...

# %%
so_data_new.loc[so_data_new.Country == 'Germany']
# Out:
#      ResponseId                                         MainBranch  \
# 12           13                     I am a developer by profession
# 20           21                     I am a developer by profession
# 24           25                     I am a developer by profession
# 25           26  I am not primarily a developer, but I write co...
# 35           36                     I am a developer by profession
# ..          ...                                                ...
# 960         961                                      None of these
# 973         974                     I am a developer by profession
# 975         976                     I am a developer by profession
# 978         979  I am not primarily a developer, but I write co...
# 997         998                     I am a developer by profession
#
#                              Employment  Country US_State UK_Country  \
# 12                   Employed full-time  Germany      NaN        NaN
# ...

# %%
so_data_new.iloc[[0,5,10,15]]
# Out:
#     ResponseId                              MainBranch           Employment  \
# 1            2  I am a student who is learning to code   Student, full-time
# 6            7             I code primarily as a hobby  I prefer not to say
# 11          12          I am a developer by profession   Employed full-time
# 16          17          I am a developer by profession   Employed full-time
#
#                      Country       US_State UK_Country  \
# 1                Netherlands            NaN        NaN
# 6   United States of America  New Hampshire        NaN
# 11                     Spain            NaN        NaN
# 16                    Turkey            NaN        NaN
#
#                                               EdLevel     Age1stCode  \
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 6   Secondary school (e.g. American high school, G...  11 - 17 years
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# ...

# %%
so_data_new2 = so_data.iloc[:1000]

# %%
so_data_new2.iloc[[0,5,10,15]]
# Out:
#     ResponseId                              MainBranch  \
# 0            1          I am a developer by profession
# 5            6  I am a student who is learning to code
# 10          11          I am a developer by profession
# 15          16  I am a student who is learning to code
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 5                                  Student, part-time
# 10                                 Employed full-time
# 15                                 Student, full-time
#
#                                               Country  US_State UK_Country  \
# 0                                            Slovakia       NaN        NaN
# 5                            United States of America   Georgia        NaN
# 10  United Kingdom of Great Britain and Northern I...       NaN    England
# 15                           United States of America  Missouri        NaN
#
# ...

# %%
so_data_new2.iloc[:5, :5]
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State
# 0                                           Slovakia      NaN
# 1                                        Netherlands      NaN
# 2                                 Russian Federation      NaN
# ...

# %%
so_data_new2.iloc[2:5, :5]
# Out:
#    ResponseId                                         MainBranch  \
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State
# 2                                 Russian Federation      NaN
# 3                                            Austria      NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN

# %%
so_data_new2.iloc[2:5, 2:5]
# Out:
#                                           Employment  \
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State
# 2                                 Russian Federation      NaN
# 3                                            Austria      NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN

# %%
so_data_new2.loc[2:5]
# Out:
#    ResponseId                                         MainBranch  \
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
#
#                                           Employment  \
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
#
#                                              Country US_State UK_Country  \
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
# 5                           United States of America  Georgia        NaN
#
# ...

# %%
so_data_new2.iloc[2:5]
# Out:
#    ResponseId                                         MainBranch  \
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                            EdLevel     Age1stCode  \
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# ...

# %%
so_data_new2[['Empolyment','Country','Age','Gender']].sort_values(by='Age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6f/cmgdlrnj78g5r1pl2dzz3y_r0000gn/T/ipykernel_15986/341579856.py in <module>
# ----> 1 so_data_new2[['Empolyment','Country','Age','Gender']].sort_values(by='Age')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
# ...

# %%
so_data_new2.query('Age < 23 and Gender == "Woman" '')
# Out:
#   File "/var/folders/6f/cmgdlrnj78g5r1pl2dzz3y_r0000gn/T/ipykernel_15986/2634159758.py", line 1
#     so_data_new2.query('Age < 23 and Gender == "Woman" '')
#                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
so_data_new2.to_csv('Reduced StackOverflow data.csv', index=False)

# %%
so_data_new2.to_excel('Reduced StackOverflow data sheet.xlsx', sheet_name='New Data')
